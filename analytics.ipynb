# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('results.csv')
df.head()
# Out:
#        name      benchmark         value             graph
# 0  NTriples           size  28708.000000  graphs/bldg1.ttl
# 1  NTriples  encoding_time      0.001744  graphs/bldg1.ttl
# 2  NTriples  encoding_time      0.002382  graphs/bldg1.ttl
# 3  NTriples  encoding_time      0.001619  graphs/bldg1.ttl
# 4  NTriples  encoding_time      0.001713  graphs/bldg1.ttl

# %%
df[df.benchmark=='size']
# Out:
#          name benchmark    value             graph
# 0    NTriples      size  28708.0  graphs/bldg1.ttl
# 201    Turtle      size  28708.0  graphs/bldg1.ttl
# 402   JSON-LD      size  81169.0  graphs/bldg1.ttl
# 603   RDF-XML      size  69758.0  graphs/bldg1.ttl

# %%
df[df.benchmark=='decoding_time'].plot.hist(by='name', figsize=(15,10))
# Out:
# array([<AxesSubplot:title={'center':'JSON-LD'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'NTriples'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'RDF-XML'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'Turtle'}, ylabel='Frequency'>],
#       dtype=object)

# %%
df[df.benchmark=='decoding_time'].groupby('name').describe()
# Out:
#           value                                                              \
#           count      mean       std       min       25%       50%       75%
# name
# JSON-LD   100.0  0.045434  0.011465  0.036666  0.037748  0.042344  0.044211
# NTriples  100.0  0.074715  0.017788  0.058099  0.061353  0.072596  0.077027
# RDF-XML   100.0  0.031588  0.009624  0.024122  0.026667  0.028067  0.031464
# Turtle    100.0  0.069105  0.020278  0.052055  0.058250  0.060350  0.068415
#
#
#                max
# name
# JSON-LD   0.091774
# NTriples  0.152235
# RDF-XML   0.077232
# Turtle    0.146866
